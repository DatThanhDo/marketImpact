# %%
import pandas as pd
df = pd.read_csv('hnx.csv',index_col= 0)

# %%
df
# Out:
#     Name  Ceiling_price  Floor_price  Local_price  Close  Change_price  \
# 0    AAV           31.1         25.5         28.3   29.6           1.3
# 1    ACM            4.0          3.4          3.7    3.5          -0.2
# 2    ADC           27.5         22.5         25.0   24.0          -1.0
# 3    AMC           26.7         21.9         24.3   24.8           0.5
# 4    AME           10.8          9.0          9.9    9.9           0.0
# ..   ...            ...          ...          ...    ...           ...
# 278  VTL           15.2         12.6         13.9   15.2           1.3
# 279  VTV            8.1          6.7          7.4    7.7           0.3
# 280  WCS          213.1        174.5        193.8  193.0          -0.8
# 281  WSS           11.9          9.9         10.9   10.9           0.0
# 282  X20           10.4          8.6          9.5    9.5           0.0
#
#      Change_percent    Volume   High    Low  Foreign_investor_buy  \
# 0               4.6  151660.0   29.8   28.3                   0.0
# 1              -5.4  321030.0    3.7    3.4                2660.0
# 2              -4.0      10.0   24.0   24.0                   0.0
# 3               2.1     390.0   24.8   24.0                   0.0
# 4               0.0     700.0    9.9    9.0                   0.0
# ..              ...       ...    ...    ...                   ...
# 278             9.4     690.0   15.2   12.6                   0.0
# 279             4.1   20670.0    7.9    7.3                   0.0
# 280            -0.4      30.0  193.0  193.0                   0.0
# 281             0.0   14350.0   11.3   10.8                   0.0
# 282             0.0     100.0    9.5    9.5                   0.0
#
#      Foregin_investor_sell
# 0                      0.0
# 1                  16790.0
# 2                      0.0
# 3                      0.0
# 4                      0.0
# ..                     ...
# 278                    0.0
# 279                    0.0
# 280                    0.0
# 281                    0.0
# 282                    0.0
#
# [283 rows x 12 columns]

# %%
stock_list = df.Name.to_list()
VN30_list = ['MBB', 'ACB', 'TCB', 'VJC', 'STB', 'VHM', 'SAB', 'HDB', 'BVH', 'CTG', 'BID', 'GAS', 
                'TPB', 'VPB', 'NVL', 'KDH', 'VCB', 'GVR', 'PLX', 'PNJ', 'SSI', 'PDR', 'POW', 'VNM', 
                'VIC', 'VRE', 'FPT', 'MWG', 'HPG', 'MSN']

# %%
for stock in VN30_list:
    if stock in stock_list:
        stock_list.remove(stock)

# %%
stock_list
# Out:
# ['AAV',
#  'ACM',
#  'ADC',
#  'AMC',
#  'AME',
#  'AMV',
#  'API',
#  'APP',
#  'APS',
#  'ART',
#  'BAB',
#  'BAX',
#  'BBS',
#  'BCC',
#  'BCF',
#  'BDB',
#  'BII',
#  'BKC',
#  'BNA',
#  'BPC',
#  'BST',
#  'BTS',
#  'BTW',
#  'BVS',
#  'C69',
#  'C92',
#  'CAG',
#  'CAN',
#  'CAP',
#  'CDN',
#  'CEO',
#  'CET',
#  'CIA',
#  'CLH',
#  'CLM',
#  'CMC',
#  'CMS',
#  'CPC',
#  'CSC',
#  'CTB',
#  'CTC',
#  'CTP',
#  'CTT',
#  'CTX',
#  'CVN',
#  'D11',
#  'DAD',
#  'DAE',
#  'DC2',
#  'DDG',
#  'DHT',
#  'DIH',
#  'DL1',
#  'DNM',
#  'DNP',
#  'DPC',
#  'DS3',
#  'DST',
#  'DTD',
#  'DTK',
#  'DVG',
#  'DXP',
#  'DZM',
#  'EID',
#  'EVS',
#  'FID',
#  'GDW',
#  'GIC',
#  'GKM',
#  'GLT',
#  'GMA',
#  'GMX',
#  'HAD',
#  'HAT',
#  'HBS',
#  'HCC',
#  'HDA',
#  'HEV',
#  'HHG',
#  'HKT',
#  'HLC',
#  'HLD\xa0*',
#  'HMH',
#  'HOM',
#  'HPM',
#  'HTC',
#  'HTP',
#  'HUT',
#  'HVT',
#  'ICG',
#  'IDC',
#  'IDJ',
#  'IDV',
#  'INN',
#  'ITQ',
#  'IVS',
#  'KDM',
#  'KHS',
#  'KKC',
#  'KLF',
#  'KMT',
#  'KSD',
#  'KSQ',
#  'KTS',
#  'KTT',
#  'KVC',
#  'L14',
#  'L18',
#  'L35',
#  'L43',
#  'L61',
#  'L62',
#  'LAS',
#  'LBE',
#  'LCS',
#  'LDP',
#  'LHC',
#  'LIG',
#  'LM7',
#  'LUT',
#  'MAC',
#  'MAS',
#  'MBG\xa0*',
#  'MBS',
#  'MCF',
#  'MCO',
#  'MDC',
#  'MED',
#  'MEL',
#  'MHL',
#  'MIM',
#  'MST',
#  'MVB',
#  'NAG',
#  'NBC',
#  'NBP',
#  'NBW',
#  'NDN',
#  'NDX',
#  'NET\xa0*',
#  'NRC',
#  'NSH',
#  'NST',
#  'NTH',
#  'NTP',
#  'NVB',
#  'OCH',
#  'ONE',
#  'PBP',
#  'PCE',
#  'PCG',
#  'PCT',
#  'PDB',
#  'PDC',
#  'PEN',
#  'PGN',
#  'PGS',
#  'PGT',
#  'PHN',
#  'PHP',
#  'PIC',
#  'PJC',
#  'PLC',
#  'PMB',
#  'PMC',
#  'PMP',
#  'POT',
#  'PPE',
#  'PPP',
#  'PPS',
#  'PPY',
#  'PRE',
#  'PSD',
#  'PSE',
#  'PSI',
#  'PSW',
#  'PTS',
#  'PV2',
#  'PVB',
#  'PVC',
#  'PVG',
#  'PVI',
#  'PVL',
#  'PVS',
#  'QTC',
#  'RCL',
#  'S55',
#  'S99',
#  'SAF',
#  'SCI',
#  'SD2',
#  'SD4',
#  'SD5',
#  'SD6',
#  'SD9',
#  'SDA',
#  'SDC',
#  'SDN',
#  'SDT',
#  'SEB',
#  'SED',
#  'SFN',
#  'SHB',
#  'SHE',
#  'SHN',
#  'SHS',
#  'SIC',
#  'SJE',
#  'SLS',
#  'SMN',
#  'SMT',
#  'SPI',
#  'SRA',
#  'SSM',
#  'STC',
#  'STP',
#  'SVN',
#  'SZB',
#  'TA9',
#  'TAR',
#  'TC6',
#  'TDN',
#  'TDT',
#  'THB',
#  'THD',
#  'THT',
#  'TIG',
#  'TJC',
#  'TKC',
#  'TKU',
#  'TMB',
#  'TMC',
#  'TMX',
#  'TNG\xa0*',
#  'TPP',
#  'TSB',
#  'TTC',
#  'TTH',
#  'TTL',
#  'TTZ',
#  'TV3',
#  'TV4',
#  'TVC',
#  'TVD',
#  'TXM',
#  'UNI',
#  'V21',
#  'VBC',
#  'VC1',
#  'VC2',
#  'VC3',
#  'VC6',
#  'VC7',
#  'VC9',
#  'VCC',
#  'VCM',
#  'VCS',
#  'VE1',
#  'VE2',
#  'VE3',
#  'VE4',
#  'VE8',
#  'VGS',
#  'VHE',
#  'VHL',
#  'VIF',
#  'VIG',
#  'VIT',
#  'VKC',
#  'VMC',
#  'VMS',
#  'VNC',
#  'VNF',
#  'VNR',
#  'VSA',
#  'VTC',
#  'VTH',
#  'VTJ',
#  'VTL',
#  'VTV',
#  'WCS',
#  'WSS',
#  'X20']
